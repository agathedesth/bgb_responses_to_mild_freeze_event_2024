# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.font_manager import FontProperties
import math
import statistics
from numpy import *
from matplotlib.pyplot import *



# Changing font to stix; setting specialized math font properties as directly as possible
rcParams['mathtext.fontset'] = 'custom'
rcParams['mathtext.it'] = 'STIXGeneral:italic'
rcParams['mathtext.bf'] = 'STIXGeneral:italic:bold'

                                    
                                            # FOR THE DATA OF SITE A - 2022


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/November_December_2022/BGB_Per_Site_December_2022.csv', header=0)
df1 = pd.DataFrame(data)
#print(df1)


                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
df = df1.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_A_layer_1_2022 = df.iloc[0, [1,2,3]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
print(site_A_layer_1_2022)
site_A_sum_layer_1_2022 = sum(site_A_layer_1_2022)
print("The sum of the sites layer 1 is", site_A_sum_layer_1_2022, "g")


# LAYER 2 - ALL SITES
site_A_layer_2_2022 = df.iloc[1, [1,2,3]]
print(site_A_layer_2_2022)
site_A_sum_layer_2_2022 = sum(site_A_layer_2_2022)
print("The sum of the sites layer 2 is", site_A_sum_layer_2_2022, "g")


# LAYER 3 - ALL SITES
site_A_layer_3_2022 = df.iloc[2, [1,2,3]]
print(site_A_layer_3_2022)
site_A_sum_layer_3_2022 = sum(site_A_layer_3_2022)
print("The sum of the sites layer 3 is", site_A_sum_layer_3_2022, "g")


# LAYER 4 - ALL SITES
site_A_layer_4_2022 = df.iloc[3, [1,2,3]]
print(site_A_layer_4_2022)
site_A_sum_layer_4_2022 = sum(site_A_layer_4_2022)
print("The sum of the sites layer 4 is", site_A_sum_layer_4_2022, "g")


# LAYER 5 - ALL SITES
site_A_layer_5_2022 = df.iloc[4, [1,2,3]]
print(site_A_layer_5_2022)
site_A_sum_layer_5_2022 = sum(site_A_layer_5_2022)
print("The sum of the sites layer 5 is", site_A_sum_layer_5_2022, "g")


# LAYER 6 - ALL SITES
site_A_layer_6_2022 = df.iloc[5, [1,2,3]]
print(site_A_layer_6_2022)
site_A_sum_layer_6_2022 = sum(site_A_layer_6_2022)
print("The sum of the sites layer 6 is", site_A_sum_layer_6_2022, "g")


# LAYER 7 - ALL SITES
site_A_layer_7_2022 = df.iloc[6, [1,2,3]]
print(site_A_layer_7_2022)
site_A_sum_layer_7_2022 = sum(site_A_layer_7_2022)
print("The sum of the sites layer 7 is", site_A_sum_layer_7_2022, "g")


# LAYER 8 - ALL SITES
site_A_layer_8_2022 = df.iloc[7, [1,2,3]]
print(site_A_layer_8_2022)
site_A_sum_layer_8_2022 = sum(site_A_layer_8_2022)
print("The sum of the sites layer 8 is", site_A_sum_layer_8_2022, "g")


# LAYER 9 - ALL SITES
site_A_layer_9_2022 = df.iloc[8, [1,2,3]]
print(site_A_layer_9_2022)
site_A_sum_layer_9_2022 = sum(site_A_layer_9_2022)
print("The sum of the sites layer 9 is", site_A_sum_layer_9_2022, "g")


# LAYER 10 - ALL SITES
site_A_layer_10_2022 = df.iloc[9, [1,2,3]]
print(site_A_layer_10_2022)
site_A_sum_layer_10_2022 = sum(site_A_layer_10_2022)
print("The sum of the sites layer 10 is", site_A_sum_layer_10_2022, "g")


# LAYER 11 - ALL SITES
site_A_layer_11_2022 = df.iloc[10, [1,2,3]]
print(site_A_layer_11_2022)
site_A_sum_layer_11_2022 = sum(site_A_layer_11_2022)
print("The sum of the sites layer 11 is", site_A_sum_layer_11_2022, "g")


# LAYER 12 - ALL SITES
site_A_layer_12_2022 = df.iloc[11, [1,2,3]]
print(site_A_layer_12_2022)
site_A_sum_layer_12_2022 = sum(site_A_layer_12_2022)
print("The sum of the sites layer 12 is", site_A_sum_layer_12_2022, "g")


# LAYER 13 - ALL SITES
site_A_layer_13_2022 = df.iloc[12, [1,2,3]]
print(site_A_layer_13_2022)
site_A_sum_layer_13_2022 = sum(site_A_layer_13_2022)
print("The sum of the sites layer 13 is", site_A_sum_layer_13_2022, "g")


# LAYER 14 - ALL SITES
site_A_layer_14_2022 = df.iloc[13, [1,2,3]]
print(site_A_layer_14_2022)
site_A_sum_layer_14_2022 = sum(site_A_layer_14_2022)
print("The sum of the sites layer 14 is", site_A_sum_layer_14_2022, "g")


# LAYER 15 - ALL SITES
site_A_layer_15_2022 = df.iloc[14, [1,2,3]]
print(site_A_layer_15_2022)
site_A_sum_layer_15_2022 = sum(site_A_layer_15_2022)
print("The sum of the sites layer 15 is", site_A_sum_layer_15_2022, "g")




                                    # TO FIND THE AREA OF THE PLASTIC CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
length_plastic_core = 0.30
area_plastic_core = (math.pi*(radius_plastic_core)**2)
print("The area of the plastic core is", area_plastic_core, "m^2")





                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2022 = 3
        

# LAYER 1 - ALL SITES
site_A_BGB_layer_1_2022_plastic = ((site_A_sum_layer_1_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_1_2022 = site_A_BGB_layer_1_2022_plastic
print("The BGB for layer 1 is:", site_A_BGB_layer_1_2022, "g m^-2")



# LAYER 2 - ALL SITES
site_A_BGB_layer_2_2022_plastic = ((site_A_sum_layer_2_2022/number_plastic_core_2022)/area_plastic_core)


site_A_BGB_layer_2_2022 = site_A_BGB_layer_2_2022_plastic
print("The BGB for layer 2 is:", site_A_BGB_layer_2_2022, "g m^-2")



# LAYER 3 - ALL SITES
site_A_BGB_layer_3_2022_plastic = ((site_A_sum_layer_3_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_3_2022 = site_A_BGB_layer_3_2022_plastic
print("The BGB for layer 3 is:", site_A_BGB_layer_3_2022, "g m^-2")



# LAYER 4 - ALL SITES
site_A_BGB_layer_4_2022_plastic = ((site_A_sum_layer_4_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_4_2022 = site_A_BGB_layer_4_2022_plastic
print("The BGB for layer 4 is:", site_A_BGB_layer_4_2022, "g m^-2")



# LAYER 5 - ALL SITES
site_A_BGB_layer_5_2022_plastic = ((site_A_sum_layer_5_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_5_2022 = site_A_BGB_layer_5_2022_plastic
print("The BGB for layer 5 is:", site_A_BGB_layer_5_2022, "g m^-2")



# LAYER 6 - ALL SITES
site_A_BGB_layer_6_2022_plastic = ((site_A_sum_layer_6_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_6_2022 = site_A_BGB_layer_6_2022_plastic
print("The BGB for layer 6 is:", site_A_BGB_layer_6_2022, "g m^-2")



# LAYER 7 - ALL SITES
site_A_BGB_layer_7_2022_plastic = ((site_A_sum_layer_7_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_7_2022 = site_A_BGB_layer_7_2022_plastic
print("The BGB for layer 7 is:", site_A_BGB_layer_7_2022, "g m^-2")



# LAYER 8 - ALL SITES
site_A_BGB_layer_8_2022_plastic = ((site_A_sum_layer_8_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_8_2022 = site_A_BGB_layer_8_2022_plastic
print("The BGB for layer 8 is:", site_A_BGB_layer_8_2022, "g m^-2")



# LAYER 9 - ALL SITES
site_A_BGB_layer_9_2022_plastic = ((site_A_sum_layer_9_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_9_2022 = site_A_BGB_layer_9_2022_plastic
print("The BGB for layer 9 is:", site_A_BGB_layer_9_2022, "g m^-2")



# LAYER 10 - ALL SITES
site_A_BGB_layer_10_2022_plastic = ((site_A_sum_layer_10_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_10_2022 = site_A_BGB_layer_10_2022_plastic
print("The BGB for layer 10 is:", site_A_BGB_layer_10_2022, "g m^-2")



# LAYER 11 - ALL SITES
site_A_BGB_layer_11_2022_plastic = ((site_A_sum_layer_11_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_11_2022 = site_A_BGB_layer_11_2022_plastic
print("The BGB for layer 11 is:", site_A_BGB_layer_11_2022, "g m^-2")



# LAYER 12 - ALL SITES
site_A_BGB_layer_12_2022_plastic = ((site_A_sum_layer_12_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_12_2022 = site_A_BGB_layer_12_2022_plastic
print("The BGB for layer 12 is:", site_A_BGB_layer_12_2022, "g m^-2")



# LAYER 13 - ALL SITES
site_A_BGB_layer_13_2022_plastic = ((site_A_sum_layer_13_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_13_2022 = site_A_BGB_layer_13_2022_plastic
print("The BGB for layer 13 is:", site_A_BGB_layer_13_2022, "g m^-2")



# LAYER 14 - ALL SITES
site_A_BGB_layer_14_2022_plastic = ((site_A_sum_layer_14_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_14_2022 = site_A_BGB_layer_14_2022_plastic
print("The BGB for layer 14 is:", site_A_BGB_layer_14_2022, "g m^-2")



# LAYER 15 - ALL SITES
site_A_BGB_layer_15_2022_plastic = ((site_A_sum_layer_15_2022/number_plastic_core_2022)/area_plastic_core)

site_A_BGB_layer_15_2022 = site_A_BGB_layer_15_2022_plastic
print("The BGB for layer 15 is:", site_A_BGB_layer_15_2022, "g m^-2")





                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    
# LAYER 1 - To find the standard deviation:
site_A_std_layer_1_2022 = (df.iloc[0, [1,2,3]].std())/area_plastic_core
print("STD site A layer 1 2022:", site_A_std_layer_1_2022)


# LAYER 2 - To find the standard deviation:
site_A_std_layer_2_2022 = (df.iloc[1, [1,2,3]].std())/area_plastic_core
print("STD site A layer 2 2022:", site_A_std_layer_2_2022)


# LAYER 3 - To find the standard deviation:
site_A_std_layer_3_2022 = (df.iloc[2, [1,2,3]].std())/area_plastic_core
print("STD site A layer 3 2022 is:", site_A_std_layer_3_2022, "g m^-2")


# LAYER 4 - To find the standard deviation:
site_A_std_layer_4_2022 = (df.iloc[3, [1,2,3]].std())/area_plastic_core
print("STD site A layer 4 2022 is:", site_A_std_layer_4_2022)


# LAYER 5 - To find the standard deviation:
site_A_std_layer_5_2022 = (df.iloc[4, [1,2,3]].std())/area_plastic_core
print("STD site A layer 5 2022 is:", site_A_std_layer_5_2022)


# LAYER 6 - To find the standard deviation:
site_A_std_layer_6_2022 = (df.iloc[5, [1,2,3]].std())/area_plastic_core
print("STD site A layer 6 2022 is:", site_A_std_layer_6_2022, "g.m^-2")


# LAYER 7 - To find the standard deviation:
site_A_std_layer_7_2022 = (df.iloc[6, [1,2,3]].std())/area_plastic_core
print("STD site A layer 7 2022 is:", site_A_std_layer_7_2022)


# LAYER 8 - To find the standard deviation:
site_A_std_layer_8_2022 = (df.iloc[7, [1,2,3]].std())/area_plastic_core
print("STD site A layer 8 2022 is:", site_A_std_layer_8_2022)


# LAYER 9 - To find the standard deviation:
site_A_std_layer_9_2022 = (df.iloc[8, [1,2,3]].std())/area_plastic_core
print("STD site A layer 9 2022 is:", site_A_std_layer_9_2022, "g.m^-2")


# LAYER 10 - To find the standard deviation:
site_A_std_layer_10_2022 = (df.iloc[9, [1,2,3]].std())/area_plastic_core
print("STD site A layer 10 2022 is:", site_A_std_layer_10_2022)


# LAYER 11 - To find the standard deviation:
site_A_std_layer_11_2022 = (df.iloc[10, [1,2,3]].std())/area_plastic_core
print("STD site A layer 11 2022 is:", site_A_std_layer_11_2022)


# LAYER 12 - To find the standard deviation:
site_A_std_layer_12_2022 = (df.iloc[11, [1,2,3]].std())/area_plastic_core
print("STD site A layer 12 2022 is:", site_A_std_layer_12_2022, "g.m^-2")


# LAYER 13 - To find the standard deviation:
site_A_std_layer_13_2022 = (df.iloc[12, [1,2,3]].std())/area_plastic_core
print("STD site A layer 13 2022 is:", site_A_std_layer_13_2022)


# LAYER 14 - To find the standard deviation:
site_A_std_layer_14_2022 = (df.iloc[13, [1,2,3]].std())/area_plastic_core
print("STD site A layer 14 2022 is:", site_A_std_layer_14_2022)


# LAYER 15 - To find the standard deviation:
site_A_std_layer_15_2022 = (df.iloc[14, [1,2,3]].std())/area_plastic_core
print("STD site A layer 15 2022 is:", site_A_std_layer_15_2022, "g.m^-2")









                                             # FOR THE DATA OF SITE A - 2023


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data1 = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/March_2023/BGB_Per_Site_March_2023.csv', header=0)
df2 = pd.DataFrame(data1)
#print(df2)


                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
dff = df2.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_A_layer_1_2023 = dff.iloc[0, [1,2,3]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
print(site_A_layer_1_2023)
site_A_sum_layer_1_2023 = sum(site_A_layer_1_2023)
print("The sum of the sites layer 1 is", site_A_sum_layer_1_2023, "g")


# LAYER 2 - ALL SITES
site_A_layer_2_2023 = dff.iloc[1, [1,2,3]]
print(site_A_layer_2_2023)
site_A_sum_layer_2_2023 = sum(site_A_layer_2_2023)
print("The sum of the sites layer 2 is", site_A_sum_layer_2_2023, "g")


# LAYER 3 - ALL SITES
site_A_layer_3_2023 = dff.iloc[2, [1,2,3]]
print(site_A_layer_3_2023)
site_A_sum_layer_3_2023 = sum(site_A_layer_3_2023)
print("The sum of the sites layer 3 is", site_A_sum_layer_3_2023, "g")


# LAYER 4 - ALL SITES
site_A_layer_4_2023 = dff.iloc[3, [1,2,3]]
print(site_A_layer_4_2023)
site_A_sum_layer_4_2023 = sum(site_A_layer_4_2023)
print("The sum of the sites layer 4 is", site_A_sum_layer_4_2023, "g")


# LAYER 5 - ALL SITES
site_A_layer_5_2023 = dff.iloc[4, [1,2,3]]
print(site_A_layer_5_2023)
site_A_sum_layer_5_2023 = sum(site_A_layer_5_2023)
print("The sum of the sites layer 5 is", site_A_sum_layer_5_2023, "g")


# LAYER 6 - ALL SITES
site_A_layer_6_2023 = dff.iloc[5, [1,2,3]]
print(site_A_layer_6_2023)
site_A_sum_layer_6_2023 = sum(site_A_layer_6_2023)
print("The sum of the sites layer 6 is", site_A_sum_layer_6_2023, "g")


# LAYER 7 - ALL SITES
site_A_layer_7_2023 = dff.iloc[6, [1,2,3]]
print(site_A_layer_7_2023)
site_A_sum_layer_7_2023 = sum(site_A_layer_7_2023)
print("The sum of the sites layer 7 is", site_A_sum_layer_7_2023, "g")


# LAYER 8 - ALL SITES
site_A_layer_8_2023 = dff.iloc[7, [1,2,3]]
print(site_A_layer_8_2023)
site_A_sum_layer_8_2023 = sum(site_A_layer_8_2023)
print("The sum of the sites layer 8 is", site_A_sum_layer_8_2023, "g")


# LAYER 9 - ALL SITES
site_A_layer_9_2023 = dff.iloc[8, [1,2,3]]
print(site_A_layer_9_2023)
site_A_sum_layer_9_2023 = sum(site_A_layer_9_2023)
print("The sum of the sites layer 9 is", site_A_sum_layer_9_2023, "g")


# LAYER 10 - ALL SITES
site_A_layer_10_2023 = dff.iloc[9, [1,2,3]]
print(site_A_layer_10_2023)
site_A_sum_layer_10_2023 = sum(site_A_layer_10_2023)
print("The sum of the sites layer 10 is", site_A_sum_layer_10_2023, "g")


# LAYER 11 - ALL SITES
site_A_layer_11_2023 = dff.iloc[10, [1,2,3]]
print(site_A_layer_11_2023)
site_A_sum_layer_11_2023 = sum(site_A_layer_11_2023)
print("The sum of the sites layer 11 is", site_A_sum_layer_11_2023, "g")


# LAYER 12 - ALL SITES
site_A_layer_12_2023 = dff.iloc[11, [1,2,3]]
print(site_A_layer_12_2023)
site_A_sum_layer_12_2023 = sum(site_A_layer_12_2023)
print("The sum of the sites layer 12 is", site_A_sum_layer_12_2023, "g")


# LAYER 13 - ALL SITES
site_A_layer_13_2023 = dff.iloc[12, [1,2,3]]
print(site_A_layer_13_2023)
site_A_sum_layer_13_2023 = sum(site_A_layer_13_2023)
print("The sum of the sites layer 13 is", site_A_sum_layer_13_2023, "g")


# LAYER 14 - ALL SITES
site_A_layer_14_2023 = dff.iloc[13, [1,2,3]]
print(site_A_layer_14_2023)
site_A_sum_layer_14_2023 = sum(site_A_layer_14_2023)
print("The sum of the sites layer 14 is", site_A_sum_layer_14_2023, "g")


# LAYER 15 - ALL SITES
site_A_layer_15_2023 = dff.iloc[14, [1,2,3]]
print(site_A_layer_15_2023)
site_A_sum_layer_15_2023 = sum(site_A_layer_15_2023)
print("The sum of the sites layer 15 is", site_A_sum_layer_15_2023, "g")






                                    # TO FIND THE AREA OF THE PLASTIC CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
length_plastic_core = 0.30
area_plastic_core = (math.pi*(radius_plastic_core)**2)





                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2023 = 3
        

# LAYER 1 - ALL SITES
site_A_BGB_layer_1_2023_plastic = ((site_A_sum_layer_1_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_1_2023 = site_A_BGB_layer_1_2023_plastic
print("The BGB for layer 1 is:", site_A_BGB_layer_1_2023, "g m^-2")



# LAYER 2 - ALL SITES
site_A_BGB_layer_2_2023_plastic = ((site_A_sum_layer_2_2023/number_plastic_core_2023)/area_plastic_core)


site_A_BGB_layer_2_2023 = site_A_BGB_layer_2_2023_plastic
print("The BGB for layer 2 is:", site_A_BGB_layer_2_2023, "g m^-2")



# LAYER 3 - ALL SITES
site_A_BGB_layer_3_2023_plastic = ((site_A_sum_layer_3_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_3_2023 = site_A_BGB_layer_3_2023_plastic
print("The BGB for layer 3 is:", site_A_BGB_layer_3_2023, "g m^-2")



# LAYER 4 - ALL SITES
site_A_BGB_layer_4_2023_plastic = ((site_A_sum_layer_4_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_4_2023 = site_A_BGB_layer_4_2023_plastic
print("The BGB for layer 4 is:", site_A_BGB_layer_4_2023, "g m^-2")



# LAYER 5 - ALL SITES
site_A_BGB_layer_5_2023_plastic = ((site_A_sum_layer_5_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_5_2023 = site_A_BGB_layer_5_2023_plastic
print("The BGB for layer 5 is:", site_A_BGB_layer_5_2023, "g m^-2")



# LAYER 6 - ALL SITES
site_A_BGB_layer_6_2023_plastic = ((site_A_sum_layer_6_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_6_2023 = site_A_BGB_layer_6_2023_plastic
print("The BGB for layer 6 is:", site_A_BGB_layer_6_2023, "g m^-2")



# LAYER 7 - ALL SITES
site_A_BGB_layer_7_2023_plastic = ((site_A_sum_layer_7_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_7_2023 = site_A_BGB_layer_7_2023_plastic
print("The BGB for layer 7 is:", site_A_BGB_layer_7_2023, "g m^-2")



# LAYER 8 - ALL SITES
site_A_BGB_layer_8_2023_plastic = ((site_A_sum_layer_8_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_8_2023 = site_A_BGB_layer_8_2023_plastic
print("The BGB for layer 8 is:", site_A_BGB_layer_8_2023, "g m^-2")



# LAYER 9 - ALL SITES
site_A_BGB_layer_9_2023_plastic = ((site_A_sum_layer_9_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_9_2023 = site_A_BGB_layer_9_2023_plastic
print("The BGB for layer 9 is:", site_A_BGB_layer_9_2023, "g m^-2")



# LAYER 10 - ALL SITES
site_A_BGB_layer_10_2023_plastic = ((site_A_sum_layer_10_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_10_2023 = site_A_BGB_layer_10_2023_plastic
print("The BGB for layer 10 is:", site_A_BGB_layer_10_2023, "g m^-2")



# LAYER 11 - ALL SITES
site_A_BGB_layer_11_2023_plastic = ((site_A_sum_layer_11_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_11_2023 = site_A_BGB_layer_11_2023_plastic
print("The BGB for layer 11 is:", site_A_BGB_layer_11_2023, "g m^-2")



# LAYER 12 - ALL SITES
site_A_BGB_layer_12_2023_plastic = ((site_A_sum_layer_12_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_12_2023 = site_A_BGB_layer_12_2023_plastic
print("The BGB for layer 12 is:", site_A_BGB_layer_12_2023, "g m^-2")



# LAYER 13 - ALL SITES
site_A_BGB_layer_13_2023_plastic = ((site_A_sum_layer_13_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_13_2023 = site_A_BGB_layer_13_2023_plastic
print("The BGB for layer 13 is:", site_A_BGB_layer_13_2023, "g m^-2")



# LAYER 14 - ALL SITES
site_A_BGB_layer_14_2023_plastic = ((site_A_sum_layer_14_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_14_2023 = site_A_BGB_layer_14_2023_plastic
print("The BGB for layer 14 is:", site_A_BGB_layer_14_2023, "g m^-2")



# LAYER 15 - ALL SITES
site_A_BGB_layer_15_2023_plastic = ((site_A_sum_layer_15_2023/number_plastic_core_2023)/area_plastic_core)

site_A_BGB_layer_15_2023 = site_A_BGB_layer_15_2023_plastic
print("The BGB for layer 15 is:", site_A_BGB_layer_15_2023, "g m^-2")





                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    
# LAYER 1 - To find the standard deviation:
site_A_std_layer_1_2023 = (dff.iloc[0, [1,2,3]].std())/area_plastic_core
print("THIS IS A TEST", site_A_std_layer_1_2023)


# LAYER 2 - To find the standard deviation:
site_A_std_layer_2_2023 = (dff.iloc[1, [1,2,3]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_A_std_layer_2_2023)


# LAYER 3 - To find the standard deviation:
site_A_std_layer_3_2023 = (dff.iloc[2, [1,2,3]].std())/area_plastic_core
print("/nThe standard deviation of the layer 3 2023 is:", site_A_std_layer_3_2023, "g.m^-2")


# LAYER 4 - To find the standard deviation:
site_A_std_layer_4_2023 = (dff.iloc[3, [1,2,3]].std())/area_plastic_core
print("THIS IS A TEST", site_A_std_layer_4_2023)


# LAYER 5 - To find the standard deviation:
site_A_std_layer_5_2023 = (dff.iloc[4, [1,2,3]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_A_std_layer_5_2023)


# LAYER 6 - To find the standard deviation:
site_A_std_layer_6_2023 = (dff.iloc[5, [1,2,3]].std())/area_plastic_core
print("/nThe standard deviation of the layer 6 2023 is:", site_A_std_layer_6_2023, "g.m^-2")


# LAYER 7 - To find the standard deviation:
site_A_std_layer_7_2023 = (dff.iloc[6, [1,2,3]].std())/area_plastic_core
print("THIS IS A TEST", site_A_std_layer_7_2023)


# LAYER 8 - To find the standard deviation:
site_A_std_layer_8_2023 = (dff.iloc[7, [1,2,3]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_A_std_layer_8_2023)


# LAYER 9 - To find the standard deviation:
site_A_std_layer_9_2023 = (dff.iloc[8, [1,2,3]].std())/area_plastic_core
print("/nThe standard deviation of the layer 9 2023 is:", site_A_std_layer_9_2023, "g.m^-2")


# LAYER 10 - To find the standard deviation:
site_A_std_layer_10_2023 = (dff.iloc[9, [1,2,3]].std())/area_plastic_core
print("THIS IS A TEST", site_A_std_layer_10_2023)


# LAYER 11 - To find the standard deviation:
site_A_std_layer_11_2023 = (dff.iloc[10, [1,2,3]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_A_std_layer_11_2023)


# LAYER 12 - To find the standard deviation:
site_A_std_layer_12_2023 = (dff.iloc[11, [1,2,3]].std())/area_plastic_core
print("/nThe standard deviation of the layer 12 2023 is:", site_A_std_layer_12_2023, "g.m^-2")


# LAYER 13 - To find the standard deviation:
site_A_std_layer_13_2023 = (dff.iloc[12, [1,2,3]].std())/area_plastic_core
print("THIS IS A TEST", site_A_std_layer_13_2023)


# LAYER 14 - To find the standard deviation:
site_A_std_layer_14_2023 = (dff.iloc[13, [1,2,3]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_A_std_layer_14_2023)


# LAYER 15 - To find the standard deviation:
site_A_std_layer_15_2023 = (dff.iloc[14, [1,2,3]].std())/area_plastic_core
print("/nThe standard deviation of the layer 15 2023 is:", site_A_std_layer_15_2023, "g.m^-2")





                                           # FOR THE DATA OF SITE B - 2022


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data2 = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/November_December_2022/BGB_Per_Site_December_2022.csv', header=0)
df3 = pd.DataFrame(data2)


                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
dfff = df3.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_B_layer_1_2022 = dfff.iloc[0, [4,5,6]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
site_B_sum_layer_1_2022 = sum(site_B_layer_1_2022)


# LAYER 2 - ALL SITES
site_B_layer_2_2022 = dfff.iloc[1, [4,5,6]]
site_B_sum_layer_2_2022 = sum(site_B_layer_2_2022)


# LAYER 3 - ALL SITES
site_B_layer_3_2022 = dfff.iloc[2, [4,5,6]]
site_B_sum_layer_3_2022 = sum(site_B_layer_3_2022)



# LAYER 4 - ALL SITES
site_B_layer_4_2022 = dfff.iloc[3, [4,5,6]]
site_B_sum_layer_4_2022 = sum(site_B_layer_4_2022)



# LAYER 5 - ALL SITES
site_B_layer_5_2022 = dfff.iloc[4, [4,5,6]]
site_B_sum_layer_5_2022 = sum(site_B_layer_5_2022)



# LAYER 6 - ALL SITES
site_B_layer_6_2022 = dfff.iloc[5, [4,5,6]]
site_B_sum_layer_6_2022 = sum(site_B_layer_6_2022)



# LAYER 7 - ALL SITES
site_B_layer_7_2022 = dfff.iloc[6, [4,5,6]]
site_B_sum_layer_7_2022 = sum(site_B_layer_7_2022)



# LAYER 8 - ALL SITES
site_B_layer_8_2022 = dfff.iloc[7, [4,5,6]]
site_B_sum_layer_8_2022 = sum(site_B_layer_8_2022)



# LAYER 9 - ALL SITES
site_B_layer_9_2022 = dfff.iloc[8, [4,5,6]]
site_B_sum_layer_9_2022 = sum(site_B_layer_9_2022)



# LAYER 10 - ALL SITES
site_B_layer_10_2022 = dfff.iloc[9, [4,5,6]]
site_B_sum_layer_10_2022 = sum(site_B_layer_10_2022)


# LAYER 11 - ALL SITES
site_B_layer_11_2022 = dfff.iloc[10, [4,5,6]]
site_B_sum_layer_11_2022 = sum(site_B_layer_11_2022)



# LAYER 12 - ALL SITES
site_B_layer_12_2022 = dfff.iloc[11, [4,5,6]]
site_B_sum_layer_12_2022 = sum(site_B_layer_12_2022)



# LAYER 13 - ALL SITES
site_B_layer_13_2022 = dfff.iloc[12, [4,5,6]]
site_B_sum_layer_13_2022 = sum(site_B_layer_13_2022)



# LAYER 14 - ALL SITES
site_B_layer_14_2022 = dfff.iloc[13, [4,5,6]]
site_B_sum_layer_14_2022 = sum(site_B_layer_14_2022)



# LAYER 15 - ALL SITES
site_B_layer_15_2022 = dfff.iloc[14, [4,5,6]]
site_B_sum_layer_15_2022 = sum(site_B_layer_15_2022)




                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # METAL CORE PART
    

# LAYER 1 - CORE 4
site_B_layer_1_core_4_2022 = dfff.iloc[0, [7]]   # This reads first row (row 0) of columns 7 and 11 to avoid the plastic cores of sites A, B and C
site_B_sum_layer_1_core_4_2022 = sum(site_B_layer_1_core_4_2022)



# LAYER 2 - CORE 4
site_B_layer_2_core_4_2022 = dfff.iloc[1, [7]]
site_B_sum_layer_2_core_4_2022 = sum(site_B_layer_2_core_4_2022)



# LAYER 3 - CORE 4
site_B_layer_3_core_4_2022 = dfff.iloc[2, [7]]
site_B_sum_layer_3_core_4_2022 = sum(site_B_layer_3_core_4_2022)



# LAYER 4 - CORE 4
site_B_layer_4_core_4_2022 = dfff.iloc[3, [7]]
site_B_sum_layer_4_core_4_2022 = sum(site_B_layer_4_core_4_2022)



# LAYER 5 - CORE 4
site_B_layer_5_core_4_2022 = dfff.iloc[4, [7]]
site_B_sum_layer_5_core_4_2022 = sum(site_B_layer_5_core_4_2022)



# LAYER 6 - CORE 4
site_B_layer_6_core_4_2022 = dfff.iloc[5, [7]]
site_B_sum_layer_6_core_4_2022 = sum(site_B_layer_6_core_4_2022)



# LAYER 7 - CORE 4
site_B_layer_7_core_4_2022 = dfff.iloc[6, [7]]
site_B_sum_layer_7_core_4_2022 = sum(site_B_layer_7_core_4_2022)



# LAYER 8 - CORE 4
site_B_layer_8_core_4_2022 = dfff.iloc[7, [7]]
site_B_sum_layer_8_core_4_2022 = sum(site_B_layer_8_core_4_2022)



# LAYER 9 - CORE 4
site_B_layer_9_core_4_2022 = dfff.iloc[8, [7]]
site_B_sum_layer_9_core_4_2022 = sum(site_B_layer_9_core_4_2022)



# LAYER 10 - CORE 4
site_B_layer_10_core_4_2022 = dfff.iloc[9, [7]]
site_B_sum_layer_10_core_4_2022 = sum(site_B_layer_10_core_4_2022)



# LAYER 11 - CORE 4
site_B_layer_11_core_4_2022 = dfff.iloc[10, [7]]
site_B_sum_layer_11_core_4_2022 = sum(site_B_layer_11_core_4_2022)



# LAYER 12 - CORE 4
site_B_layer_12_core_4_2022 = dfff.iloc[11, [7]]
site_B_sum_layer_12_core_4_2022 = sum(site_B_layer_12_core_4_2022)



# LAYER 13 - CORE 4
site_B_layer_13_core_4_2022 = dfff.iloc[12, [7]]
site_B_sum_layer_13_core_4_2022 = sum(site_B_layer_13_core_4_2022)



# LAYER 14 - CORE 4
site_B_layer_14_core_4_2022 = dfff.iloc[13, [7]]
site_B_sum_layer_14_core_4_2022 = sum(site_B_layer_14_core_4_2022)


# LAYER 15 - CORE 4
site_B_layer_15_core_4_2022 = dfff.iloc[14, [7]]
site_B_sum_layer_15_core_4_2022 = sum(site_B_layer_15_core_4_2022)





                                    # TO FIND THE AREA OF THE PLASTIC AND METAL CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
area_plastic_core = (math.pi*(radius_plastic_core)**2)
print("The area of the plastic core is", area_plastic_core, "m^2")


# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_metal_core = 0.072
radius_metal_core = diameter_metal_core/2
area_metal_core = (math.pi*(radius_metal_core)**2)
print("the area of the metal core is", area_metal_core, "m^2")




                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2022 = 3
number_metal_core_2022 = 1
        

# LAYER 1 - ALL SITES
site_B_BGB_layer_1_2022_plastic = ((site_B_sum_layer_1_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_1_2022_metal = ((site_B_sum_layer_1_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_1_2022 = site_B_BGB_layer_1_2022_plastic+site_B_BGB_layer_1_2022_metal
print("The BGB for layer 1 is:", site_B_BGB_layer_1_2022, "g m^-2")



# LAYER 2 - ALL SITES
site_B_BGB_layer_2_2022_plastic = ((site_B_sum_layer_2_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_2_2022_metal = ((site_B_sum_layer_2_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_2_2022 = site_B_BGB_layer_2_2022_plastic+site_B_BGB_layer_2_2022_metal
print("The BGB for layer 2 is:", site_B_BGB_layer_2_2022, "g m^-2")



# LAYER 3 - ALL SITES
site_B_BGB_layer_3_2022_plastic = ((site_B_sum_layer_3_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_3_2022_metal = ((site_B_sum_layer_3_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_3_2022 = site_B_BGB_layer_3_2022_plastic+site_B_BGB_layer_3_2022_metal
print("The BGB for layer 3 is:", site_B_BGB_layer_3_2022, "g m^-2")



# LAYER 4 - ALL SITES
site_B_BGB_layer_4_2022_plastic = ((site_B_sum_layer_4_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_4_2022_metal = ((site_B_sum_layer_4_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_4_2022 = site_B_BGB_layer_4_2022_plastic+site_B_BGB_layer_4_2022_metal
print("The BGB for layer 4 is:", site_B_BGB_layer_4_2022, "g m^-2")



# LAYER 5 - ALL SITES
site_B_BGB_layer_5_2022_plastic = ((site_B_sum_layer_5_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_5_2022_metal = ((site_B_sum_layer_5_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_5_2022 = site_B_BGB_layer_5_2022_plastic+site_B_BGB_layer_5_2022_metal
print("The BGB for layer 5 is:", site_B_BGB_layer_5_2022, "g m^-2")



# LAYER 6 - ALL SITES
site_B_BGB_layer_6_2022_plastic = ((site_B_sum_layer_6_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_6_2022_metal = ((site_B_sum_layer_6_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_6_2022 = site_B_BGB_layer_6_2022_plastic+site_B_BGB_layer_6_2022_metal
print("The BGB for layer 6 is:", site_B_BGB_layer_6_2022, "g m^-2")



# LAYER 7 - ALL SITES
site_B_BGB_layer_7_2022_plastic = ((site_B_sum_layer_7_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_7_2022_metal = ((site_B_sum_layer_7_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_7_2022 = site_B_BGB_layer_7_2022_plastic+site_B_BGB_layer_7_2022_metal
print("The BGB for layer 7 is:", site_B_BGB_layer_7_2022, "g m^-2")



# LAYER 8 - ALL SITES
site_B_BGB_layer_8_2022_plastic = ((site_B_sum_layer_8_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_8_2022_metal = ((site_B_sum_layer_8_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_8_2022 = site_B_BGB_layer_8_2022_plastic+site_B_BGB_layer_8_2022_metal
print("The BGB for layer 8 is:", site_B_BGB_layer_8_2022, "g m^-2")



# LAYER 9 - ALL SITES
site_B_BGB_layer_9_2022_plastic = ((site_B_sum_layer_9_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_9_2022_metal = ((site_B_sum_layer_9_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_9_2022 = site_B_BGB_layer_9_2022_plastic+site_B_BGB_layer_9_2022_metal
print("The BGB for layer 9 is:", site_B_BGB_layer_9_2022, "g m^-2")



# LAYER 10 - ALL SITES
site_B_BGB_layer_10_2022_plastic = ((site_B_sum_layer_10_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_10_2022_metal = ((site_B_sum_layer_10_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_10_2022 = site_B_BGB_layer_10_2022_plastic+site_B_BGB_layer_10_2022_metal
print("The BGB for layer 10 is:", site_B_BGB_layer_10_2022, "g m^-2")



# LAYER 11 - ALL SITES
site_B_BGB_layer_11_2022_plastic = ((site_B_sum_layer_11_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_11_2022_metal = ((site_B_sum_layer_11_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_11_2022 = site_B_BGB_layer_11_2022_plastic+site_B_BGB_layer_11_2022_metal
print("The BGB for layer 11 is:", site_B_BGB_layer_11_2022, "g m^-2")



# LAYER 12 - ALL SITES
site_B_BGB_layer_12_2022_plastic = ((site_B_sum_layer_12_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_12_2022_metal = ((site_B_sum_layer_12_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_12_2022 = site_B_BGB_layer_12_2022_plastic+site_B_BGB_layer_12_2022_metal
print("The BGB for layer 12 is:", site_B_BGB_layer_12_2022, "g m^-2")




# LAYER 13 - ALL SITES
site_B_BGB_layer_13_2022_plastic = ((site_B_sum_layer_13_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_13_2022_metal = ((site_B_sum_layer_13_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_13_2022 = site_B_BGB_layer_13_2022_plastic+site_B_BGB_layer_13_2022_metal
print("The BGB for layer 13 is:", site_B_BGB_layer_13_2022, "g m^-2")



# LAYER 14 - ALL SITES
site_B_BGB_layer_14_2022_plastic = ((site_B_sum_layer_14_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_14_2022_metal = ((site_B_sum_layer_14_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_14_2022 = site_B_BGB_layer_14_2022_plastic+site_B_BGB_layer_14_2022_metal
print("The BGB for layer 14 is:", site_B_BGB_layer_14_2022, "g m^-2")



# LAYER 15 - ALL SITES
site_B_BGB_layer_15_2022_plastic = ((site_B_sum_layer_15_2022/number_plastic_core_2022)/area_plastic_core)

site_B_BGB_layer_15_2022_metal = ((site_B_sum_layer_15_core_4_2022/number_metal_core_2022)/area_metal_core)

site_B_BGB_layer_15_2022 = site_B_BGB_layer_15_2022_plastic+site_B_BGB_layer_15_2022_metal
print("The BGB for layer 15 is:", site_B_BGB_layer_15_2022, "g m^-2")




                              
                              

                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    

# LAYER 1 - To find the standard deviation:
site_B_std_layer_1_2022 = (dfff.iloc[0, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_1_2022)


# LAYER 2 - To find the standard deviation:
site_B_std_layer_2_2022 = (dfff.iloc[1, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_2_2022)


# LAYER 3 - To find the standard deviation:
site_B_std_layer_3_2022 = (dfff.iloc[2, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 3 2022 is:", site_B_std_layer_3_2022, "g.m^-2")


# LAYER 4 - To find the standard deviation:
site_B_std_layer_4_2022 = (dfff.iloc[3, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_4_2022)


# LAYER 5 - To find the standard deviation:
site_B_std_layer_5_2022 = (dfff.iloc[4, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_5_2022)


# LAYER 6 - To find the standard deviation:
site_B_std_layer_6_2022 = (dfff.iloc[5, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 6 2022 is:", site_B_std_layer_6_2022, "g.m^-2")


# LAYER 7 - To find the standard deviation:
site_B_std_layer_7_2022 = (dfff.iloc[6, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_7_2022)


# LAYER 8 - To find the standard deviation:
site_B_std_layer_8_2022 = (dfff.iloc[7, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_8_2022)


# LAYER 9 - To find the standard deviation:
site_B_std_layer_9_2022 = (dfff.iloc[8, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 9 2022 is:", site_B_std_layer_9_2022, "g.m^-2")


# LAYER 10 - To find the standard deviation:
site_B_std_layer_10_2022 = (dfff.iloc[9, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_10_2022)


# LAYER 11 - To find the standard deviation:
site_B_std_layer_11_2022 = (dfff.iloc[10, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_11_2022)


# LAYER 12 - To find the standard deviation:
site_B_std_layer_12_2022 = (dfff.iloc[11, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 12 2022 is:", site_B_std_layer_12_2022, "g.m^-2")


# LAYER 13 - To find the standard deviation:
site_B_std_layer_13_2022 = (dfff.iloc[12, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_13_2022)


# LAYER 14 - To find the standard deviation:
site_B_std_layer_14_2022 = (dfff.iloc[13, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_14_2022)


# LAYER 15 - To find the standard deviation:
site_B_std_layer_15_2022 = (dfff.iloc[14, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 15 2022 is:", site_B_std_layer_15_2022, "g.m^-2")









                                           # FOR THE DATA OF SITE B - 2023


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data3 = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/March_2023/BGB_Per_Site_March_2023.csv', header=0)
df4 = pd.DataFrame(data3)



                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
dffff = df4.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_B_layer_1_2023 = dffff.iloc[0, [4,5,6]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
site_B_sum_layer_1_2023 = sum(site_B_layer_1_2023)


# LAYER 2 - ALL SITES
site_B_layer_2_2023 = dffff.iloc[1, [4,5,6]]
site_B_sum_layer_2_2023 = sum(site_B_layer_2_2023)


# LAYER 3 - ALL SITES
site_B_layer_3_2023 = dffff.iloc[2, [4,5,6]]
site_B_sum_layer_3_2023 = sum(site_B_layer_3_2023)


# LAYER 4 - ALL SITES
site_B_layer_4_2023 = dffff.iloc[3, [4,5,6]]
site_B_sum_layer_4_2023 = sum(site_B_layer_4_2023)


# LAYER 5 - ALL SITES
site_B_layer_5_2023 = dffff.iloc[4, [4,5,6]]
site_B_sum_layer_5_2023 = sum(site_B_layer_5_2023)


# LAYER 6 - ALL SITES
site_B_layer_6_2023 = dffff.iloc[5, [4,5,6]]
site_B_sum_layer_6_2023 = sum(site_B_layer_6_2023)


# LAYER 7 - ALL SITES
site_B_layer_7_2023 = dffff.iloc[6, [4,5,6]]
site_B_sum_layer_7_2023 = sum(site_B_layer_7_2023)


# LAYER 8 - ALL SITES
site_B_layer_8_2023 = dffff.iloc[7, [4,5,6]]
site_B_sum_layer_8_2023 = sum(site_B_layer_8_2023)


# LAYER 9 - ALL SITES
site_B_layer_9_2023 = dffff.iloc[8, [4,5,6]]
site_B_sum_layer_9_2023 = sum(site_B_layer_9_2023)


# LAYER 10 - ALL SITES
site_B_layer_10_2023 = dffff.iloc[9, [4,5,6]]
site_B_sum_layer_10_2023 = sum(site_B_layer_10_2023)


# LAYER 11 - ALL SITES
site_B_layer_11_2023 = dffff.iloc[10, [4,5,6]]
site_B_sum_layer_11_2023 = sum(site_B_layer_11_2023)


# LAYER 12 - ALL SITES
site_B_layer_12_2023 = dffff.iloc[11, [4,5,6]]
site_B_sum_layer_12_2023 = sum(site_B_layer_12_2023)


# LAYER 13 - ALL SITES
site_B_layer_13_2023 = dffff.iloc[12, [4,5,6]]
site_B_sum_layer_13_2023 = sum(site_B_layer_13_2023)


# LAYER 14 - ALL SITES
site_B_layer_14_2023 = dffff.iloc[13, [4,5,6]]
site_B_sum_layer_14_2023 = sum(site_B_layer_14_2023)


# LAYER 15 - ALL SITES
site_B_layer_15_2023 = dffff.iloc[14, [4,5,6]]
site_B_sum_layer_15_2023 = sum(site_B_layer_15_2023)




                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # METAL CORE PART
    

# LAYER 1 - CORE 4
site_B_layer_1_core_4_2023 = dffff.iloc[0, [7]]   # This reads first row (row 0) of columns 7 and 11 to avoid the plastic cores of sites A, B and C
site_B_sum_layer_1_core_4_2023 = sum(site_B_layer_1_core_4_2023)


# LAYER 2 - CORE 4
site_B_layer_2_core_4_2023 = dffff.iloc[1, [7]]
site_B_sum_layer_2_core_4_2023 = sum(site_B_layer_2_core_4_2023)


# LAYER 3 - CORE 4
site_B_layer_3_core_4_2023 = dffff.iloc[2, [7]]
site_B_sum_layer_3_core_4_2023 = sum(site_B_layer_3_core_4_2023)


# LAYER 4 - CORE 4
site_B_layer_4_core_4_2023 = dffff.iloc[3, [7]]
site_B_sum_layer_4_core_4_2023 = sum(site_B_layer_4_core_4_2023)


# LAYER 5 - CORE 4
site_B_layer_5_core_4_2023 = dffff.iloc[4, [7]]
site_B_sum_layer_5_core_4_2023 = sum(site_B_layer_5_core_4_2023)


# LAYER 6 - CORE 4
site_B_layer_6_core_4_2023 = dffff.iloc[5, [7]]
site_B_sum_layer_6_core_4_2023 = sum(site_B_layer_6_core_4_2023)


# LAYER 7 - CORE 4
site_B_layer_7_core_4_2023 = dffff.iloc[6, [7]]
site_B_sum_layer_7_core_4_2023 = sum(site_B_layer_7_core_4_2023)


# LAYER 8 - CORE 4
site_B_layer_8_core_4_2023 = dffff.iloc[7, [7]]
site_B_sum_layer_8_core_4_2023 = sum(site_B_layer_8_core_4_2023)


# LAYER 9 - CORE 4
site_B_layer_9_core_4_2023 = dffff.iloc[8, [7]]
site_B_sum_layer_9_core_4_2023 = sum(site_B_layer_9_core_4_2023)


# LAYER 10 - CORE 4
site_B_layer_10_core_4_2023 = dffff.iloc[9, [7]]
site_B_sum_layer_10_core_4_2023 = sum(site_B_layer_10_core_4_2023)


# LAYER 11 - CORE 4
site_B_layer_11_core_4_2023 = dffff.iloc[10, [7]]
site_B_sum_layer_11_core_4_2023 = sum(site_B_layer_11_core_4_2023)


# LAYER 12 - CORE 4
site_B_layer_12_core_4_2023 = dffff.iloc[11, [7]]
site_B_sum_layer_12_core_4_2023 = sum(site_B_layer_12_core_4_2023)


# LAYER 13 - CORE 4
site_B_layer_13_core_4_2023 = dffff.iloc[12, [7]]
site_B_sum_layer_13_core_4_2023 = sum(site_B_layer_13_core_4_2023)


# LAYER 14 - CORE 4
site_B_layer_14_core_4_2023 = dffff.iloc[13, [7]]
site_B_sum_layer_14_core_4_2023 = sum(site_B_layer_14_core_4_2023)


# LAYER 15 - CORE 4
site_B_layer_15_core_4_2023 = dffff.iloc[14, [7]]
site_B_sum_layer_15_core_4_2023 = sum(site_B_layer_15_core_4_2023)




                                    # TO FIND THE AREA OF THE PLASTIC AND METAL CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
area_plastic_core = (math.pi*(radius_plastic_core)**2)



# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_metal_core = 0.072
radius_metal_core = diameter_metal_core/2
area_metal_core = (math.pi*(radius_metal_core)**2)





                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2023 = 3
number_metal_core_2023 = 1
        

# LAYER 1 - ALL SITES
site_B_BGB_layer_1_2023_plastic = ((site_B_sum_layer_1_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_1_2023_metal = ((site_B_sum_layer_1_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_1_2023 = site_B_BGB_layer_1_2023_plastic+site_B_BGB_layer_1_2023_metal
print("The BGB for layer 1 is:", site_B_BGB_layer_1_2023, "g m^-2")



# LAYER 2 - ALL SITES
site_B_BGB_layer_2_2023_plastic = ((site_B_sum_layer_2_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_2_2023_metal = ((site_B_sum_layer_2_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_2_2023 = site_B_BGB_layer_2_2023_plastic+site_B_BGB_layer_2_2023_metal
print("The BGB for layer 2 is:", site_B_BGB_layer_2_2023, "g m^-2")



# LAYER 3 - ALL SITES
site_B_BGB_layer_3_2023_plastic = ((site_B_sum_layer_3_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_3_2023_metal = ((site_B_sum_layer_3_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_3_2023 = site_B_BGB_layer_3_2023_plastic+site_B_BGB_layer_3_2023_metal
print("The BGB for layer 3 is:", site_B_BGB_layer_3_2023, "g m^-2")



# LAYER 4 - ALL SITES
site_B_BGB_layer_4_2023_plastic = ((site_B_sum_layer_4_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_4_2023_metal = ((site_B_sum_layer_4_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_4_2023 = site_B_BGB_layer_4_2023_plastic+site_B_BGB_layer_4_2023_metal
print("The BGB for layer 4 is:", site_B_BGB_layer_4_2023, "g m^-2")



# LAYER 5 - ALL SITES
site_B_BGB_layer_5_2023_plastic = ((site_B_sum_layer_5_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_5_2023_metal = ((site_B_sum_layer_5_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_5_2023 = site_B_BGB_layer_5_2023_plastic+site_B_BGB_layer_5_2023_metal
print("The BGB for layer 5 is:", site_B_BGB_layer_5_2023, "g m^-2")



# LAYER 6 - ALL SITES
site_B_BGB_layer_6_2023_plastic = ((site_B_sum_layer_6_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_6_2023_metal = ((site_B_sum_layer_6_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_6_2023 = site_B_BGB_layer_6_2023_plastic+site_B_BGB_layer_6_2023_metal
print("The BGB for layer 6 is:", site_B_BGB_layer_6_2023, "g m^-2")



# LAYER 7 - ALL SITES
site_B_BGB_layer_7_2023_plastic = ((site_B_sum_layer_7_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_7_2023_metal = ((site_B_sum_layer_7_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_7_2023 = site_B_BGB_layer_7_2023_plastic+site_B_BGB_layer_7_2023_metal
print("The BGB for layer 7 is:", site_B_BGB_layer_7_2023, "g m^-2")



# LAYER 8 - ALL SITES
site_B_BGB_layer_8_2023_plastic = ((site_B_sum_layer_8_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_8_2023_metal = ((site_B_sum_layer_8_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_8_2023 = site_B_BGB_layer_8_2023_plastic+site_B_BGB_layer_8_2023_metal
print("The BGB for layer 8 is:", site_B_BGB_layer_8_2023, "g m^-2")



# LAYER 9 - ALL SITES
site_B_BGB_layer_9_2023_plastic = ((site_B_sum_layer_9_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_9_2023_metal = ((site_B_sum_layer_9_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_9_2023 = site_B_BGB_layer_9_2023_plastic+site_B_BGB_layer_9_2023_metal
print("The BGB for layer 9 is:", site_B_BGB_layer_9_2023, "g m^-2")



# LAYER 10 - ALL SITES
site_B_BGB_layer_10_2023_plastic = ((site_B_sum_layer_10_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_10_2023_metal = ((site_B_sum_layer_10_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_10_2023 = site_B_BGB_layer_10_2023_plastic+site_B_BGB_layer_10_2023_metal
print("The BGB for layer 10 is:", site_B_BGB_layer_10_2023, "g m^-2")



# LAYER 11 - ALL SITES
site_B_BGB_layer_11_2023_plastic = ((site_B_sum_layer_11_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_11_2023_metal = ((site_B_sum_layer_11_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_11_2023 = site_B_BGB_layer_11_2023_plastic+site_B_BGB_layer_11_2023_metal
print("The BGB for layer 11 is:", site_B_BGB_layer_11_2023, "g m^-2")



# LAYER 12 - ALL SITES
site_B_BGB_layer_12_2023_plastic = ((site_B_sum_layer_12_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_12_2023_metal = ((site_B_sum_layer_12_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_12_2023 = site_B_BGB_layer_12_2023_plastic+site_B_BGB_layer_12_2023_metal
print("The BGB for layer 12:", site_B_BGB_layer_12_2023, "g m^-2")



# LAYER 13 - ALL SITES
site_B_BGB_layer_13_2023_plastic = ((site_B_sum_layer_13_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_13_2023_metal = ((site_B_sum_layer_13_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_13_2023 = site_B_BGB_layer_13_2023_plastic+site_B_BGB_layer_13_2023_metal
print("The BGB for layer 13 is:", site_B_BGB_layer_13_2023, "g m^-2")



# LAYER 14 - ALL SITES
site_B_BGB_layer_14_2023_plastic = ((site_B_sum_layer_14_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_14_2023_metal = ((site_B_sum_layer_14_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_14_2023 = site_B_BGB_layer_14_2023_plastic+site_B_BGB_layer_14_2023_metal
print("The BGB for layer 14 is:", site_B_BGB_layer_14_2023, "g m^-2")



# LAYER 15 - ALL SITES
site_B_BGB_layer_15_2023_plastic = ((site_B_sum_layer_15_2023/number_plastic_core_2023)/area_plastic_core)

site_B_BGB_layer_15_2023_metal = ((site_B_sum_layer_15_core_4_2023/number_metal_core_2023)/area_metal_core)

site_B_BGB_layer_15_2023 = site_B_BGB_layer_15_2023_plastic+site_B_BGB_layer_15_2023_metal
print("The BGB for layer 15 is:", site_B_BGB_layer_15_2023, "g m^-2")



                              
                              

                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    

# LAYER 1 - To find the standard deviation:
site_B_std_layer_1_2023 = (dffff.iloc[0, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_1_2023)


# LAYER 2 - To find the standard deviation:
site_B_std_layer_2_2023 = (dffff.iloc[1, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_2_2023)


# LAYER 3 - To find the standard deviation:
site_B_std_layer_3_2023 = (dffff.iloc[2, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 3 2022 is:", site_B_std_layer_3_2023, "g.m^-2")


# LAYER 4 - To find the standard deviation:
site_B_std_layer_4_2023 = (dffff.iloc[3, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_4_2023)


# LAYER 5 - To find the standard deviation:
site_B_std_layer_5_2023 = (dffff.iloc[4, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_5_2023)


# LAYER 6 - To find the standard deviation:
site_B_std_layer_6_2023 = (dffff.iloc[5, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 6 2022 is:", site_B_std_layer_6_2023, "g.m^-2")


# LAYER 7 - To find the standard deviation:
site_B_std_layer_7_2023 = (dffff.iloc[6, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_7_2023)


# LAYER 8 - To find the standard deviation:
site_B_std_layer_8_2023 = (dffff.iloc[7, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_8_2023)


# LAYER 9 - To find the standard deviation:
site_B_std_layer_9_2023 = (dffff.iloc[8, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 9 2022 is:", site_B_std_layer_9_2023, "g.m^-2")


# LAYER 10 - To find the standard deviation:
site_B_std_layer_10_2023 = (dffff.iloc[9, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_10_2023)


# LAYER 11 - To find the standard deviation:
site_B_std_layer_11_2023 = (dffff.iloc[10, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_11_2023)


# LAYER 12 - To find the standard deviation:
site_B_std_layer_12_2023 = (dffff.iloc[11, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 12 2022 is:", site_B_std_layer_12_2023, "g.m^-2")


# LAYER 13 - To find the standard deviation:
site_B_std_layer_13_2023 = (dffff.iloc[12, [4,5,6]].std())/area_plastic_core
print("THIS IS A TEST", site_B_std_layer_13_2023)


# LAYER 14 - To find the standard deviation:
site_B_std_layer_14_2023 = (dffff.iloc[13, [4,5,6]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_B_std_layer_14_2023)


# LAYER 15 - To find the standard deviation:
site_B_std_layer_15_2023 = (dffff.iloc[14, [4,5,6]].std())/area_plastic_core
print("/nThe standard deviation of the layer 15 2022 is:", site_B_std_layer_15_2023, "g.m^-2")




                                                # FOR THE DATA OF SITE C - 2022


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data4 = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/November_December_2022/BGB_Per_Site_December_2022.csv', header=0)
df5 = pd.DataFrame(data4)



                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
dfc = df5.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_C_layer_1_2022 = dfc.iloc[0, [8,9,10]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
site_C_sum_layer_1_2022 = sum(site_C_layer_1_2022)


# LAYER 2 - ALL SITES
site_C_layer_2_2022 = dfc.iloc[1, [8,9,10]]
site_C_sum_layer_2_2022 = sum(site_C_layer_2_2022)


# LAYER 3 - ALL SITES
site_C_layer_3_2022 = dfc.iloc[2, [8,9,10]]
site_C_sum_layer_3_2022 = sum(site_C_layer_3_2022)


# LAYER 4 - ALL SITES
site_C_layer_4_2022 = dfc.iloc[3, [8,9,10]]
site_C_sum_layer_4_2022 = sum(site_C_layer_4_2022)


# LAYER 5 - ALL SITES
site_C_layer_5_2022 = dfc.iloc[4, [8,9,10]]
site_C_sum_layer_5_2022 = sum(site_C_layer_5_2022)


# LAYER 6 - ALL SITES
site_C_layer_6_2022 = dfc.iloc[5, [8,9,10]]
site_C_sum_layer_6_2022 = sum(site_C_layer_6_2022)


# LAYER 7 - ALL SITES
site_C_layer_7_2022 = dfc.iloc[6, [8,9,10]]
site_C_sum_layer_7_2022 = sum(site_C_layer_7_2022)


# LAYER 8 - ALL SITES
site_C_layer_8_2022 = dfc.iloc[7, [8,9,10]]
site_C_sum_layer_8_2022 = sum(site_C_layer_8_2022)


# LAYER 9 - ALL SITES
site_C_layer_9_2022 = dfc.iloc[8, [8,9,10]]
site_C_sum_layer_9_2022 = sum(site_C_layer_9_2022)


# LAYER 10 - ALL SITES
site_C_layer_10_2022 = dfc.iloc[9, [8,9,10]]
site_C_sum_layer_10_2022 = sum(site_C_layer_10_2022)


# LAYER 11 - ALL SITES
site_C_layer_11_2022 = dfc.iloc[10, [8,9,10]]
site_C_sum_layer_11_2022 = sum(site_C_layer_11_2022)


# LAYER 12 - ALL SITES
site_C_layer_12_2022 = dfc.iloc[11, [8,9,10]]
site_C_sum_layer_12_2022 = sum(site_C_layer_12_2022)


# LAYER 13 - ALL SITES
site_C_layer_13_2022 = dfc.iloc[12, [8,9,10]]
site_C_sum_layer_13_2022 = sum(site_C_layer_13_2022)


# LAYER 14 - ALL SITES
site_C_layer_14_2022 = dfc.iloc[13, [8,9,10]]
site_C_sum_layer_14_2022 = sum(site_C_layer_14_2022)


# LAYER 15 - ALL SITES
site_C_layer_15_2022 = dfc.iloc[14, [8,9,10]]
site_C_sum_layer_15_2022 = sum(site_C_layer_15_2022)




                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # METAL CORE PART
    

# LAYER 1 - CORE 4
site_C_layer_1_core_4_2022 = dfc.iloc[0, [11]]   # This reads first row (row 0) of columns 7 and 11 to avoid the plastic cores of sites A, B and C
site_C_sum_layer_1_core_4_2022 = sum(site_C_layer_1_core_4_2022)


# LAYER 2 - CORE 4
site_C_layer_2_core_4_2022 = dfc.iloc[1, [11]]
site_C_sum_layer_2_core_4_2022 = sum(site_C_layer_2_core_4_2022)


# LAYER 3 - CORE 4
site_C_layer_3_core_4_2022 = dfc.iloc[2, [11]]
site_C_sum_layer_3_core_4_2022 = sum(site_C_layer_3_core_4_2022)


# LAYER 4 - CORE 4
site_C_layer_4_core_4_2022 = dfc.iloc[3, [11]]
site_C_sum_layer_4_core_4_2022 = sum(site_C_layer_4_core_4_2022)


# LAYER 5 - CORE 4
site_C_layer_5_core_4_2022 = dfc.iloc[4, [11]]
site_C_sum_layer_5_core_4_2022 = sum(site_C_layer_5_core_4_2022)


# LAYER 6 - CORE 4
site_C_layer_6_core_4_2022 = dfc.iloc[5, [11]]
site_C_sum_layer_6_core_4_2022 = sum(site_C_layer_6_core_4_2022)


# LAYER 7 - CORE 4
site_C_layer_7_core_4_2022 = dfc.iloc[6, [11]]
site_C_sum_layer_7_core_4_2022 = sum(site_C_layer_7_core_4_2022)


# LAYER 8 - CORE 4
site_C_layer_8_core_4_2022 = dfc.iloc[7, [11]]
site_C_sum_layer_8_core_4_2022 = sum(site_C_layer_8_core_4_2022)


# LAYER 9 - CORE 4
site_C_layer_9_core_4_2022 = dfc.iloc[8, [11]]
site_C_sum_layer_9_core_4_2022 = sum(site_C_layer_9_core_4_2022)


# LAYER 10 - CORE 4
site_C_layer_10_core_4_2022 = dfc.iloc[9, [11]]
site_C_sum_layer_10_core_4_2022 = sum(site_C_layer_10_core_4_2022)


# LAYER 11 - CORE 4
site_C_layer_11_core_4_2022 = dfc.iloc[10, [11]]
site_C_sum_layer_11_core_4_2022 = sum(site_C_layer_11_core_4_2022)


# LAYER 12 - CORE 4
site_C_layer_12_core_4_2022 = dfc.iloc[11, [11]]
site_C_sum_layer_12_core_4_2022 = sum(site_C_layer_12_core_4_2022)


# LAYER 13 - CORE 4
site_C_layer_13_core_4_2022 = dfc.iloc[12, [11]]
site_C_sum_layer_13_core_4_2022 = sum(site_C_layer_13_core_4_2022)


# LAYER 14 - CORE 4
site_C_layer_14_core_4_2022 = dfc.iloc[13, [11]]
site_C_sum_layer_14_core_4_2022 = sum(site_C_layer_14_core_4_2022)


# LAYER 15 - CORE 4
site_C_layer_15_core_4_2022 = dfc.iloc[14, [11]]
site_C_sum_layer_15_core_4_2022 = sum(site_C_layer_15_core_4_2022)




                                    # TO FIND THE AREA OF THE PLASTIC AND METAL CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
area_plastic_core = (math.pi*(radius_plastic_core)**2)



# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_metal_core = 0.072
radius_metal_core = diameter_metal_core/2
area_metal_core = (math.pi*(radius_metal_core)**2)





                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2022 = 3
number_metal_core_2022 = 1
        

# LAYER 1 - ALL SITES
site_C_BGB_layer_1_2022_plastic = ((site_C_sum_layer_1_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_1_2022_metal = ((site_C_sum_layer_1_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_1_2022 = site_C_BGB_layer_1_2022_plastic+site_C_BGB_layer_1_2022_metal
print("The BGB for layer 1 is:", site_C_BGB_layer_1_2022, "g m^-2")



# LAYER 2 - ALL SITES
site_C_BGB_layer_2_2022_plastic = ((site_C_sum_layer_2_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_2_2022_metal = ((site_C_sum_layer_2_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_2_2022 = site_C_BGB_layer_2_2022_plastic+site_C_BGB_layer_2_2022_metal
print("The BGB for layer 2 is:", site_C_BGB_layer_2_2022, "g m^-2")



# LAYER 3 - ALL SITES
site_C_BGB_layer_3_2022_plastic = ((site_C_sum_layer_3_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_3_2022_metal = ((site_C_sum_layer_3_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_3_2022 = site_C_BGB_layer_3_2022_plastic+site_C_BGB_layer_3_2022_metal
print("The BGB for layer 3 is:", site_C_BGB_layer_3_2022, "g m^-2")



# LAYER 4 - ALL SITES
site_C_BGB_layer_4_2022_plastic = ((site_C_sum_layer_4_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_4_2022_metal = ((site_C_sum_layer_4_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_4_2022 = site_C_BGB_layer_4_2022_plastic+site_C_BGB_layer_4_2022_metal
print("The BGB for layer 4 is:", site_C_BGB_layer_4_2022, "g m^-2")



# LAYER 5 - ALL SITES
site_C_BGB_layer_5_2022_plastic = ((site_C_sum_layer_5_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_5_2022_metal = ((site_C_sum_layer_5_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_5_2022 = site_C_BGB_layer_5_2022_plastic+site_C_BGB_layer_5_2022_metal
print("The BGB for layer 5 is:", site_C_BGB_layer_5_2022, "g m^-2")



# LAYER 6 - ALL SITES
site_C_BGB_layer_6_2022_plastic = ((site_C_sum_layer_6_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_6_2022_metal = ((site_C_sum_layer_6_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_6_2022 = site_C_BGB_layer_6_2022_plastic+site_C_BGB_layer_6_2022_metal
print("The BGB for layer 6 is:", site_C_BGB_layer_6_2022, "g m^-2")



# LAYER 7 - ALL SITES
site_C_BGB_layer_7_2022_plastic = ((site_C_sum_layer_7_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_7_2022_metal = ((site_C_sum_layer_7_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_7_2022 = site_C_BGB_layer_7_2022_plastic+site_C_BGB_layer_7_2022_metal
print("The BGB for layer 7 is:", site_C_BGB_layer_7_2022, "g m^-2")



# LAYER 8 - ALL SITES
site_C_BGB_layer_8_2022_plastic = ((site_C_sum_layer_8_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_8_2022_metal = ((site_C_sum_layer_8_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_8_2022 = site_C_BGB_layer_8_2022_plastic+site_C_BGB_layer_8_2022_metal
print("The BGB for layer 8 is:", site_C_BGB_layer_8_2022, "g m^-2")



# LAYER 9 - ALL SITES
site_C_BGB_layer_9_2022_plastic = ((site_C_sum_layer_9_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_9_2022_metal = ((site_C_sum_layer_9_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_9_2022 = site_C_BGB_layer_9_2022_plastic+site_C_BGB_layer_9_2022_metal
print("The BGB for layer 9 is:", site_C_BGB_layer_9_2022, "g m^-2")



# LAYER 10 - ALL SITES
site_C_BGB_layer_10_2022_plastic = ((site_C_sum_layer_10_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_10_2022_metal = ((site_C_sum_layer_10_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_10_2022 = site_C_BGB_layer_10_2022_plastic+site_C_BGB_layer_10_2022_metal
print("The BGB for layer 10 is:", site_C_BGB_layer_10_2022, "g m^-2")



# LAYER 11 - ALL SITES
site_C_BGB_layer_11_2022_plastic = ((site_C_sum_layer_11_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_11_2022_metal = ((site_C_sum_layer_11_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_11_2022 = site_C_BGB_layer_11_2022_plastic+site_C_BGB_layer_11_2022_metal
print("The BGB for layer 11 is:", site_C_BGB_layer_11_2022, "g m^-2")



# LAYER 12 - ALL SITES
site_C_BGB_layer_12_2022_plastic = ((site_C_sum_layer_12_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_12_2022_metal = ((site_C_sum_layer_12_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_12_2022 = site_C_BGB_layer_12_2022_plastic+site_C_BGB_layer_12_2022_metal
print("The BGB for layer 12 is:", site_C_BGB_layer_12_2022, "g m^-2")




# LAYER 13 - ALL SITES
site_C_BGB_layer_13_2022_plastic = ((site_C_sum_layer_13_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_13_2022_metal = ((site_C_sum_layer_13_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_13_2022 = site_C_BGB_layer_13_2022_plastic+site_C_BGB_layer_13_2022_metal
print("The BGB for layer 13 is:", site_C_BGB_layer_13_2022, "g m^-2")



# LAYER 14 - ALL SITES
site_C_BGB_layer_14_2022_plastic = ((site_C_sum_layer_14_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_14_2022_metal = ((site_C_sum_layer_14_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_14_2022 = site_C_BGB_layer_14_2022_plastic+site_C_BGB_layer_14_2022_metal
print("The BGB for layer 14 is:", site_C_BGB_layer_14_2022, "g m^-2")



# LAYER 15 - ALL SITES
site_C_BGB_layer_15_2022_plastic = ((site_C_sum_layer_15_2022/number_plastic_core_2022)/area_plastic_core)

site_C_BGB_layer_15_2022_metal = ((site_C_sum_layer_15_core_4_2022/number_metal_core_2022)/area_metal_core)

site_C_BGB_layer_15_2022 = site_C_BGB_layer_15_2022_plastic+site_C_BGB_layer_15_2022_metal
print("The BGB for layer 15 is:", site_C_BGB_layer_15_2022, "g m^-2")


   
                              

                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    

# LAYER 1 - To find the standard deviation:
site_C_std_layer_1_2022 = (dfc.iloc[0, [8,9,10]].std())/area_plastic_core
print("THIS IS A TEST", site_C_std_layer_1_2022)


# LAYER 2 - To find the standard deviation:
site_C_std_layer_2_2022 = (dfc.iloc[1, [8,9,10]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_C_std_layer_2_2022)


# LAYER 3 - To find the standard deviation:
site_C_std_layer_3_2022 = (dfc.iloc[2, [8,9,10]].std())/area_plastic_core
print("/nThe standard deviation of the layer 3 2022 is:", site_C_std_layer_3_2022, "g.m^-2")


# LAYER 4 - To find the standard deviation:
site_C_std_layer_4_2022 = (dfc.iloc[3, [8,9,10]].std())/area_plastic_core
print("THIS IS A TEST", site_C_std_layer_4_2022)


# LAYER 5 - To find the standard deviation:
site_C_std_layer_5_2022 = (dfc.iloc[4, [8,9,10]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_C_std_layer_5_2022)


# LAYER 6 - To find the standard deviation:
site_C_std_layer_6_2022 = (dfc.iloc[5, [8,9,10]].std())/area_plastic_core
print("/nThe standard deviation of the layer 6 2022 is:", site_C_std_layer_6_2022, "g.m^-2")


# LAYER 7 - To find the standard deviation:
site_C_std_layer_7_2022 = (dfc.iloc[6, [8,9,10]].std())/area_plastic_core
print("THIS IS A TEST", site_C_std_layer_7_2022)


# LAYER 8 - To find the standard deviation:
site_C_std_layer_8_2022 = (dfc.iloc[7, [8,9,10]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_C_std_layer_8_2022)


# LAYER 9 - To find the standard deviation:
site_C_std_layer_9_2022 = (dfc.iloc[8, [8,9,10]].std())/area_plastic_core
print("/nThe standard deviation of the layer 9 2022 is:", site_C_std_layer_9_2022, "g.m^-2")


# LAYER 10 - To find the standard deviation:
site_C_std_layer_10_2022 = (dfc.iloc[9, [8,9,10]].std())/area_plastic_core
print("THIS IS A TEST", site_C_std_layer_10_2022)


# LAYER 11 - To find the standard deviation:
site_C_std_layer_11_2022 = (dfc.iloc[10, [8,9,10]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_C_std_layer_11_2022)


# LAYER 12 - To find the standard deviation:
site_C_std_layer_12_2022 = (dfc.iloc[11, [8,9,10]].std())/area_plastic_core
print("/nThe standard deviation of the layer 12 2022 is:", site_C_std_layer_12_2022, "g.m^-2")


# LAYER 13 - To find the standard deviation:
site_C_std_layer_13_2022 = (dfc.iloc[12, [8,9,10]].std())/area_plastic_core
print("THIS IS A TEST", site_C_std_layer_13_2022)


# LAYER 14 - To find the standard deviation:
site_C_std_layer_14_2022 = (dfc.iloc[13, [8,9,10]].std())/area_plastic_core
print("AND ANOTHER TEEESTTT", site_C_std_layer_14_2022)


# LAYER 15 - To find the standard deviation:
site_C_std_layer_15_2022 = (dfc.iloc[14, [8,9,10]].std())/area_plastic_core
print("/nThe standard deviation of the layer 15 2022 is:", site_C_std_layer_15_2022, "g.m^-2")








                                             # FOR THE DATA OF SITE C - 2023


                                            # TO IMPORT THE DATA FROM CSV
    
# To import data: (Note, I took out the index -- that was making it treat the first column differently)
data5 = pd.read_csv('/Users/agathe/Library/CloudStorage/OneDrive-UniversityofNewOrleans/Foster-Martinez_Coastal_Interactions_Lab_shared/Agathe_Desthomas_Progress_Reports/Python/March_2023/BGB_Per_Site_March_2023.csv', header=0)
df6 = pd.DataFrame(data5)
print(df6)


                                       # TO CHANGE THE FONT STYLE OF THE PLOT

# For the plot font:
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')


                               # TO GET RID OF THE NaN VALUES (EMPTY CELLS) FROM THE CSV FILE

# To get rid of the NaN values (empty cells in csv/excel) and replace them by 0.000:
dffc = df6.fillna(0.000)



                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # PLASTIC CORE PART

        
# LAYER 1 - ALL SITES
site_C_layer_1_2023 = dffc.iloc[0, [8,9,10]]   # This reads first row (row 0) of columns 0,1,2,3,4,5,6,8,9,10 to avoid cores 4 of sites B and C
site_C_sum_layer_1_2023 = sum(site_C_layer_1_2023)


# LAYER 2 - ALL SITES
site_C_layer_2_2023 = dffc.iloc[1, [8,9,10]]
site_C_sum_layer_2_2023 = sum(site_C_layer_2_2023)


# LAYER 3 - ALL SITES
site_C_layer_3_2023 = dffc.iloc[2, [8,9,10]]
site_C_sum_layer_3_2023 = sum(site_C_layer_3_2023)


# LAYER 4 - ALL SITES
site_C_layer_4_2023 = dffc.iloc[3, [8,9,10]]
site_C_sum_layer_4_2023 = sum(site_C_layer_4_2023)


# LAYER 5 - ALL SITES
site_C_layer_5_2023 = dffc.iloc[4, [8,9,10]]
site_C_sum_layer_5_2023 = sum(site_C_layer_5_2023)


# LAYER 6 - ALL SITES
site_C_layer_6_2023 = dffc.iloc[5, [8,9,10]]
site_C_sum_layer_6_2023 = sum(site_C_layer_6_2023)


# LAYER 7 - ALL SITES
site_C_layer_7_2023 = dffc.iloc[6, [8,9,10]]
site_C_sum_layer_7_2023 = sum(site_C_layer_7_2023)


# LAYER 8 - ALL SITES
site_C_layer_8_2023 = dffc.iloc[7, [8,9,10]]
site_C_sum_layer_8_2023 = sum(site_C_layer_8_2023)


# LAYER 9 - ALL SITES
site_C_layer_9_2023 = dffc.iloc[8, [8,9,10]]
site_C_sum_layer_9_2023 = sum(site_C_layer_9_2023)


# LAYER 10 - ALL SITES
site_C_layer_10_2023 = dffc.iloc[9, [8,9,10]]
site_C_sum_layer_10_2023 = sum(site_C_layer_10_2023)


# LAYER 11 - ALL SITES
site_C_layer_11_2023 = dffc.iloc[10, [8,9,10]]
site_C_sum_layer_11_2023 = sum(site_C_layer_11_2023)


# LAYER 12 - ALL SITES
site_C_layer_12_2023 = dffc.iloc[11, [8,9,10]]
site_C_sum_layer_12_2023 = sum(site_C_layer_12_2023)


# LAYER 13 - ALL SITES
site_C_layer_13_2023 = dffc.iloc[12, [8,9,10]]
site_C_sum_layer_13_2023 = sum(site_C_layer_13_2023)


# LAYER 14 - ALL SITES
site_C_layer_14_2023 = dffc.iloc[13, [8,9,10]]
site_C_sum_layer_14_2023 = sum(site_C_layer_14_2023)


# LAYER 15 - ALL SITES
site_C_layer_15_2023 = dffc.iloc[14, [8,9,10]]
site_C_sum_layer_15_2023 = sum(site_C_layer_15_2023)




                                        # TO GET THE SUM OF EACH LAYER 
    
                                              # METAL CORE PART
    

# LAYER 1 - CORE 4
site_C_layer_1_core_4_2023 = dffc.iloc[0, [11]]   # This reads first row (row 0) of columns 7 and 11 to avoid the plastic cores of sites A, B and C
site_C_sum_layer_1_core_4_2023 = sum(site_C_layer_1_core_4_2023)


# LAYER 2 - CORE 4
site_C_layer_2_core_4_2023 = dffc.iloc[1, [11]]
site_C_sum_layer_2_core_4_2023 = sum(site_C_layer_2_core_4_2023)


# LAYER 3 - CORE 4
site_C_layer_3_core_4_2023 = dffc.iloc[2, [11]]
site_C_sum_layer_3_core_4_2023 = sum(site_C_layer_3_core_4_2023)


# LAYER 4 - CORE 4
site_C_layer_4_core_4_2023 = dffc.iloc[3, [11]]
site_C_sum_layer_4_core_4_2023 = sum(site_C_layer_4_core_4_2023)


# LAYER 5 - CORE 4
site_C_layer_5_core_4_2023 = dffc.iloc[4, [11]]
site_C_sum_layer_5_core_4_2023 = sum(site_C_layer_5_core_4_2023)


# LAYER 6 - CORE 4
site_C_layer_6_core_4_2023 = dffc.iloc[5, [11]]
site_C_sum_layer_6_core_4_2023 = sum(site_C_layer_6_core_4_2023)


# LAYER 7 - CORE 4
site_C_layer_7_core_4_2023 = dffc.iloc[6, [11]]
site_C_sum_layer_7_core_4_2023 = sum(site_C_layer_7_core_4_2023)


# LAYER 8 - CORE 4
site_C_layer_8_core_4_2023 = dffc.iloc[7, [11]]
site_C_sum_layer_8_core_4_2023 = sum(site_C_layer_8_core_4_2023)


# LAYER 9 - CORE 4
site_C_layer_9_core_4_2023 = dffc.iloc[8, [11]]
site_C_sum_layer_9_core_4_2023 = sum(site_C_layer_9_core_4_2023)


# LAYER 10 - CORE 4
site_C_layer_10_core_4_2023 = dffc.iloc[9, [11]]
site_C_sum_layer_10_core_4_2023 = sum(site_C_layer_10_core_4_2023)


# LAYER 11 - CORE 4
site_C_layer_11_core_4_2023 = dffc.iloc[10, [11]]
site_C_sum_layer_11_core_4_2023 = sum(site_C_layer_11_core_4_2023)


# LAYER 12 - CORE 4
site_C_layer_12_core_4_2023 = dffc.iloc[11, [11]]
site_C_sum_layer_12_core_4_2023 = sum(site_C_layer_12_core_4_2023)


# LAYER 13 - CORE 4
site_C_layer_13_core_4_2023 = dffc.iloc[12, [11]]
site_C_sum_layer_13_core_4_2023 = sum(site_C_layer_13_core_4_2023)


# LAYER 14 - CORE 4
site_C_layer_14_core_4_2023 = dffc.iloc[13, [11]]
site_C_sum_layer_14_core_4_2023 = sum(site_C_layer_14_core_4_2023)


# LAYER 15 - CORE 4
site_C_layer_15_core_4_2023 = dffc.iloc[14, [11]]
site_C_sum_layer_15_core_4_2023 = sum(site_C_layer_15_core_4_2023)




                                    # TO FIND THE AREA OF THE PLASTIC AND METAL CORES

# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_plastic_core = 0.10
radius_plastic_core = diameter_plastic_core/2
area_plastic_core = (math.pi*(radius_plastic_core)**2)



# To find the area of the plastic core when core was entirely filled (0.30m):
diameter_metal_core = 0.072
radius_metal_core = diameter_metal_core/2
area_metal_core = (math.pi*(radius_metal_core)**2)





                           # TO FIND THE BGB BY TAKING THE SUM AND DIVIDING IT BY THE AREA OF THE CORE
    
# Number of cores for each layers                                          
number_plastic_core_2023 = 3
number_metal_core_2023 = 1
        

# LAYER 1 - ALL SITES
site_C_BGB_layer_1_2023_plastic = ((site_C_sum_layer_1_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_1_2023_metal = ((site_C_sum_layer_1_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_1_2023 = site_C_BGB_layer_1_2023_plastic+site_C_BGB_layer_1_2023_metal
print("The BGB for layer 1 is:", site_C_BGB_layer_1_2023, "g m^-2")



# LAYER 2 - ALL SITES
site_C_BGB_layer_2_2023_plastic = ((site_C_sum_layer_2_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_2_2023_metal = ((site_C_sum_layer_2_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_2_2023 = site_C_BGB_layer_2_2023_plastic+site_C_BGB_layer_2_2023_metal
print("The BGB for layer 2 is:", site_C_BGB_layer_2_2023, "g m^-2")



# LAYER 3 - ALL SITES
site_C_BGB_layer_3_2023_plastic = ((site_C_sum_layer_3_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_3_2023_metal = ((site_C_sum_layer_3_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_3_2023 = site_C_BGB_layer_3_2023_plastic+site_C_BGB_layer_3_2023_metal
print("The BGB for layer 3 is:", site_C_BGB_layer_3_2023, "g m^-2")



# LAYER 4 - ALL SITES
site_C_BGB_layer_4_2023_plastic = ((site_C_sum_layer_4_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_4_2023_metal = ((site_C_sum_layer_4_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_4_2023 = site_C_BGB_layer_4_2023_plastic+site_C_BGB_layer_4_2023_metal
print("The BGB for layer 4 is:", site_C_BGB_layer_4_2023, "g m^-2")



# LAYER 5 - ALL SITES
site_C_BGB_layer_5_2023_plastic = ((site_C_sum_layer_5_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_5_2023_metal = ((site_C_sum_layer_5_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_5_2023 = site_C_BGB_layer_5_2023_plastic+site_C_BGB_layer_5_2023_metal
print("The BGB for layer 5 is:", site_C_BGB_layer_5_2023, "g m^-2")



# LAYER 6 - ALL SITES
site_C_BGB_layer_6_2023_plastic = ((site_C_sum_layer_6_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_6_2023_metal = ((site_C_sum_layer_6_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_6_2023 = site_C_BGB_layer_6_2023_plastic+site_C_BGB_layer_6_2023_metal
print("The BGB for layer 6 is:", site_C_BGB_layer_6_2023, "g m^-2")



# LAYER 7 - ALL SITES
site_C_BGB_layer_7_2023_plastic = ((site_C_sum_layer_7_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_7_2023_metal = ((site_C_sum_layer_7_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_7_2023 = site_C_BGB_layer_7_2023_plastic+site_C_BGB_layer_7_2023_metal
print("The BGB for layer 7 is:", site_C_BGB_layer_7_2023, "g m^-2")



# LAYER 8 - ALL SITES
site_C_BGB_layer_8_2023_plastic = ((site_C_sum_layer_8_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_8_2023_metal = ((site_C_sum_layer_8_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_8_2023 = site_C_BGB_layer_8_2023_plastic+site_C_BGB_layer_8_2023_metal
print("The BGB for layer 8 is:", site_C_BGB_layer_8_2023, "g m^-2")



# LAYER 9 - ALL SITES
site_C_BGB_layer_9_2023_plastic = ((site_C_sum_layer_9_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_9_2023_metal = ((site_C_sum_layer_9_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_9_2023 = site_C_BGB_layer_9_2023_plastic+site_C_BGB_layer_9_2023_metal
print("The BGB for layer 9 is:", site_C_BGB_layer_9_2023, "g m^-2")



# LAYER 10 - ALL SITES
site_C_BGB_layer_10_2023_plastic = ((site_C_sum_layer_10_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_10_2023_metal = ((site_C_sum_layer_10_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_10_2023 = site_C_BGB_layer_10_2023_plastic+site_C_BGB_layer_10_2023_metal
print("The BGB for layer 10 is:", site_C_BGB_layer_10_2023, "g m^-2")



# LAYER 11 - ALL SITES
site_C_BGB_layer_11_2023_plastic = ((site_C_sum_layer_11_2023/number_plastic_core_2023)/area_plastic_core)
                                 
site_C_BGB_layer_11_2023_metal = ((site_C_sum_layer_11_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_11_2023 = site_C_BGB_layer_11_2023_plastic+site_C_BGB_layer_11_2023_metal
print("The BGB for layer 11 is:", site_C_BGB_layer_11_2023, "g m^-2")



# LAYER 12 - ALL SITES
site_C_BGB_layer_12_2023_plastic = ((site_C_sum_layer_12_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_12_2023_metal = ((site_C_sum_layer_12_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_12_2023 = site_C_BGB_layer_12_2023_plastic+site_C_BGB_layer_12_2023_metal
print("The BGB for layer 12 is:", site_C_BGB_layer_12_2023, "g m^-2")




# LAYER 13 - ALL SITES
site_C_BGB_layer_13_2023_plastic = ((site_C_sum_layer_13_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_13_2023_metal = ((site_C_sum_layer_13_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_13_2023 = site_C_BGB_layer_13_2023_plastic+site_C_BGB_layer_13_2023_metal
print("The BGB for layer 13 is:", site_C_BGB_layer_13_2023, "g m^-2")



# LAYER 14 - ALL SITES
site_C_BGB_layer_14_2023_plastic = ((site_C_sum_layer_14_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_14_2023_metal = ((site_C_sum_layer_14_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_14_2023 = site_C_BGB_layer_14_2023_plastic+site_C_BGB_layer_14_2023_metal
print("The BGB for layer 14 is:", site_C_BGB_layer_14_2023, "g m^-2")



# LAYER 15 - ALL SITES
site_C_BGB_layer_15_2023_plastic = ((site_C_sum_layer_15_2023/number_plastic_core_2023)/area_plastic_core)

site_C_BGB_layer_15_2023_metal = ((site_C_sum_layer_15_core_4_2023/number_metal_core_2023)/area_metal_core)

site_C_BGB_layer_15_2023 = site_C_BGB_layer_15_2023_plastic+site_C_BGB_layer_15_2023_metal
print("The BGB for layer 15 is:", site_C_BGB_layer_15_2023, "g m^-2")


   
                              

                              # TO FIND THE SAMPLE STANDARD DEVIATION OF EACH SITES
    

# LAYER 1 - To find the standard deviation:
site_C_std_layer_1_2023 = (dffc.iloc[0, [8,9,10]].std())/area_plastic_core


# LAYER 2 - To find the standard deviation:
site_C_std_layer_2_2023 = (dffc.iloc[1, [8,9,10]].std())/area_plastic_core


# LAYER 3 - To find the standard deviation:
site_C_std_layer_3_2023 = (dffc.iloc[2, [8,9,10]].std())/area_plastic_core


# LAYER 4 - To find the standard deviation:
site_C_std_layer_4_2023 = (dffc.iloc[3, [8,9,10]].std())/area_plastic_core


# LAYER 5 - To find the standard deviation:
site_C_std_layer_5_2023 = (dffc.iloc[4, [8,9,10]].std())/area_plastic_core


# LAYER 6 - To find the standard deviation:
site_C_std_layer_6_2023 = (dffc.iloc[5, [8,9,10]].std())/area_plastic_core


# LAYER 7 - To find the standard deviation:
site_C_std_layer_7_2023 = (dffc.iloc[6, [8,9,10]].std())/area_plastic_core


# LAYER 8 - To find the standard deviation:
site_C_std_layer_8_2023 = (dffc.iloc[7, [8,9,10]].std())/area_plastic_core


# LAYER 9 - To find the standard deviation:
site_C_std_layer_9_2023 = (dffc.iloc[8, [8,9,10]].std())/area_plastic_core

# LAYER 10 - To find the standard deviation:
site_C_std_layer_10_2023 = (dffc.iloc[9, [8,9,10]].std())/area_plastic_core


# LAYER 11 - To find the standard deviation:
site_C_std_layer_11_2023 = (dffc.iloc[10, [8,9,10]].std())/area_plastic_core


# LAYER 12 - To find the standard deviation:
site_C_std_layer_12_2023 = (dffc.iloc[11, [8,9,10]].std())/area_plastic_core


# LAYER 13 - To find the standard deviation:
site_C_std_layer_13_2023 = (dffc.iloc[12, [8,9,10]].std())/area_plastic_core


# LAYER 14 - To find the standard deviation:
site_C_std_layer_14_2023 = (dffc.iloc[13, [8,9,10]].std())/area_plastic_core


# LAYER 15 - To find the standard deviation:
site_C_std_layer_15_2023 = (dffc.iloc[14, [8,9,10]].std())/area_plastic_core







                                      # TO PREPARE THE SITE A - 2022 DATA TO PLOT

# To prepare the data for the plot:
x = [site_A_BGB_layer_1_2022, site_A_BGB_layer_2_2022, site_A_BGB_layer_3_2022, site_A_BGB_layer_4_2022, site_A_BGB_layer_5_2022, site_A_BGB_layer_6_2022, site_A_BGB_layer_7_2022, site_A_BGB_layer_8_2022, site_A_BGB_layer_9_2022, site_A_BGB_layer_10_2022, site_A_BGB_layer_11_2022, site_A_BGB_layer_12_2022, site_A_BGB_layer_13_2022, site_A_BGB_layer_14_2022, site_A_BGB_layer_15_2022]
y = df['Depth (m)']

# For the error bars:
e = [site_A_std_layer_1_2022, site_A_std_layer_2_2022, site_A_std_layer_3_2022, site_A_std_layer_4_2022, site_A_std_layer_5_2022, site_A_std_layer_6_2022, site_A_std_layer_7_2022, site_A_std_layer_8_2022, site_A_std_layer_9_2022, site_A_std_layer_10_2022, site_A_std_layer_11_2022, site_A_std_layer_12_2022, site_A_std_layer_13_2022, site_A_std_layer_14_2022, site_A_std_layer_15_2022] 



                                       # TO PREPARE THE SITE A - 2023 DATA TO PLOT

# To prepare the data for the plot:
a = [site_A_BGB_layer_1_2023, site_A_BGB_layer_2_2023, site_A_BGB_layer_3_2023, site_A_BGB_layer_4_2023, site_A_BGB_layer_5_2023, site_A_BGB_layer_6_2023, site_A_BGB_layer_7_2023, site_A_BGB_layer_8_2023, site_A_BGB_layer_9_2023, site_A_BGB_layer_10_2023, site_A_BGB_layer_11_2023, site_A_BGB_layer_12_2023, site_A_BGB_layer_13_2023, site_A_BGB_layer_14_2023, site_A_BGB_layer_15_2023]
b = df['Depth (m)']

# For the error bars:
c = [site_A_std_layer_1_2023, site_A_std_layer_2_2023, site_A_std_layer_3_2023, site_A_std_layer_4_2023, site_A_std_layer_5_2023, site_A_std_layer_6_2023, site_A_std_layer_7_2023, site_A_std_layer_8_2023, site_A_std_layer_9_2023, site_A_std_layer_10_2023, site_A_std_layer_11_2023, site_A_std_layer_12_2023, site_A_std_layer_13_2023, site_A_std_layer_14_2023, site_A_std_layer_15_2023] 






                                            # TO PREPARE THE SITE B - 2022 DATA TO PLOT

# To prepare the data for the plot:
xb = [site_B_BGB_layer_1_2022, site_B_BGB_layer_2_2022, site_B_BGB_layer_3_2022, site_B_BGB_layer_4_2022, site_B_BGB_layer_5_2022, site_B_BGB_layer_6_2022, site_B_BGB_layer_7_2022, site_B_BGB_layer_8_2022, site_B_BGB_layer_9_2022, site_B_BGB_layer_10_2022, site_B_BGB_layer_11_2022, site_B_BGB_layer_12_2022, site_B_BGB_layer_13_2022, site_B_BGB_layer_14_2022, site_B_BGB_layer_15_2022]
yb = df['Depth (m)']

# For the error bars:
eb = [site_B_std_layer_1_2022, site_B_std_layer_2_2022, site_B_std_layer_3_2022, site_B_std_layer_4_2022, site_B_std_layer_5_2022, site_B_std_layer_6_2022, site_B_std_layer_7_2022, site_B_std_layer_8_2022, site_B_std_layer_9_2022, site_B_std_layer_10_2022, site_B_std_layer_11_2022, site_B_std_layer_12_2022, site_B_std_layer_13_2022, site_B_std_layer_14_2022, site_B_std_layer_15_2022] 




                                            # TO PREPARE THE SITE B - 2023 DATA TO PLOT

# To prepare the data for the plot:
ab = [site_B_BGB_layer_1_2023, site_B_BGB_layer_2_2023, site_B_BGB_layer_3_2023, site_B_BGB_layer_4_2023, site_B_BGB_layer_5_2023, site_B_BGB_layer_6_2023, site_B_BGB_layer_7_2023, site_B_BGB_layer_8_2023, site_B_BGB_layer_9_2023, site_B_BGB_layer_10_2023, site_B_BGB_layer_11_2023, site_B_BGB_layer_12_2023, site_B_BGB_layer_13_2023, site_B_BGB_layer_14_2023, site_B_BGB_layer_15_2023]
bb = df['Depth (m)']

# For the error bars:
cb = [site_B_std_layer_1_2023, site_B_std_layer_2_2023, site_B_std_layer_3_2023, site_B_std_layer_4_2023, site_B_std_layer_5_2023, site_B_std_layer_6_2023, site_B_std_layer_7_2023, site_B_std_layer_8_2023, site_B_std_layer_9_2023, site_B_std_layer_10_2023, site_B_std_layer_11_2023, site_B_std_layer_12_2023, site_B_std_layer_13_2023, site_B_std_layer_14_2023, site_B_std_layer_15_2023] 








                                            # TO PREPARE THE SITE C - 2022 DATA TO PLOT

# To prepare the data for the plot:
xc = [site_C_BGB_layer_1_2022, site_C_BGB_layer_2_2022, site_C_BGB_layer_3_2022, site_C_BGB_layer_4_2022, site_C_BGB_layer_5_2022, site_C_BGB_layer_6_2022, site_C_BGB_layer_7_2022, site_C_BGB_layer_8_2022, site_C_BGB_layer_9_2022, site_C_BGB_layer_10_2022, site_C_BGB_layer_11_2022, site_C_BGB_layer_12_2022, site_C_BGB_layer_13_2022, site_C_BGB_layer_14_2022, site_C_BGB_layer_15_2022]
yc = dfc['Depth (m)']

# For the error bars:
ec = [site_C_std_layer_1_2022, site_C_std_layer_2_2022, site_C_std_layer_3_2022, site_C_std_layer_4_2022, site_C_std_layer_5_2022, site_C_std_layer_6_2022, site_C_std_layer_7_2022, site_C_std_layer_8_2022, site_C_std_layer_9_2022, site_C_std_layer_10_2022, site_C_std_layer_11_2022, site_C_std_layer_12_2022, site_C_std_layer_13_2022, site_C_std_layer_14_2022, site_C_std_layer_15_2022] 






                                            # TO PREPARE THE SITE C - 2023 DATA TO PLOT

# To prepare the data for the plot:
ac = [site_C_BGB_layer_1_2023, site_C_BGB_layer_2_2023, site_C_BGB_layer_3_2023, site_C_BGB_layer_4_2023, site_C_BGB_layer_5_2023, site_C_BGB_layer_6_2023, site_C_BGB_layer_7_2023, site_C_BGB_layer_8_2023, site_C_BGB_layer_9_2023, site_C_BGB_layer_10_2023, site_C_BGB_layer_11_2023, site_C_BGB_layer_12_2023, site_C_BGB_layer_13_2023, site_C_BGB_layer_14_2023, site_C_BGB_layer_15_2023]
bc = dfc['Depth (m)']

# For the error bars:
cc = [site_C_std_layer_1_2023, site_C_std_layer_2_2023, site_C_std_layer_3_2023, site_C_std_layer_4_2023, site_C_std_layer_5_2023, site_C_std_layer_6_2023, site_C_std_layer_7_2023, site_C_std_layer_8_2023, site_C_std_layer_9_2023, site_C_std_layer_10_2023, site_C_std_layer_11_2023, site_C_std_layer_12_2023, site_C_std_layer_13_2023, site_C_std_layer_14_2023, site_C_std_layer_15_2023] 










                                        # TO PLOT ON A GRAPH


#fig, ax = plt.subplots()
fig, ax = plt.subplots(figsize=(15, 6))


# SITE A - data of 2022
ax.plot(x, y, color='silver') 
leg1 = ax.errorbar(x, y, yerr=None, xerr=e, fmt='', ecolor=None, lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='silver',  marker='o', markersize=6, markeredgewidth=1)

# SITE A - data of 2023
ax.plot(a, b, color='dimgrey', linestyle=':') 
leg2 = ax.errorbar(a, b, yerr=None, xerr=c, fmt='', ecolor=None, linestyle=':', lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='dimgrey', marker='o', markersize=6, markeredgewidth=1, fillstyle='none')


# SITE B - data 2022
ax.plot(xb, yb, color='silver')
leg3 = ax.errorbar(xb, yb, yerr=None, xerr=eb, fmt='', ecolor=None, lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='silver',  marker='*', markersize=10, markeredgewidth=1)

# SITE B - data 2023
ax.plot(ab, bb, color='dimgrey', linestyle=':')
leg4 = ax.errorbar(ab, bb, yerr=None, xerr=cb, fmt='', ecolor=None, linestyle=':', lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='dimgrey', marker='*', markersize=10, markeredgewidth=1, fillstyle='none')



# SITE C - data 2022
ax.plot(xc, yc, color='silver') 
leg5 = ax.errorbar(xc, yc, yerr=None, xerr=ec, fmt='', ecolor=None, lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='silver', marker='d', markersize=8, markeredgewidth=1)

# SITE C - data 2023
ax.plot(ac, bc, color='dimgrey', linestyle=':') #data of 2023
leg6 = ax.errorbar(ac, bc, yerr=None, xerr=cc, fmt='', ecolor=None, linestyle=':', lw=0.7, elinewidth=0.5, capsize=2, barsabove=False, color='dimgrey', marker='d', markersize=8, markeredgewidth=1, fillstyle='none')




# To get the legend
ax.legend(handles=[leg1, leg2, leg3, leg4, leg5, leg6], labels=["Edge Before Mild Freeze", "Edge After Mild Freeze", "Inland Before Mild Freeze", "Inland After Mild Freeze", "Natural Before Mild Freeze", "Natural After Mild Freeze"], loc='lower right', handlelength=3, numpoints=1, fontsize=9, frameon=False)


# For the y ticks
yticks = np.arange(-0.30,0,0.05) #change the data in the csv to negative so it will plot the smaller numbers (0.05 for example) closer to the surface (top)
ax.set_yticks(yticks)            
ax.set_yticklabels(['0.30','0.25','0.20','0.15','0.10','0.05'], fontproperties=font) #label the ticks so the depths don't show as negative 


# For the number of x ticks:
ax.xaxis.set_major_locator(plt.MaxNLocator(6))



#plt.title("Vertical Belowground Biomass of $\mathbf{Avicennia}$ $\mathbf{germinans}$ (g m$^{-2}$) in West Belle Island, LA,\n""Before the December 2022 Mild Freezing Event In Different Sites.", size = '18', fontproperties=font, fontweight='bold', pad = '12')

plt.xlabel("Belowground Biomass (g m$^{-2}$) of $\it{Avicennia}$ $\it{germinans}$.", size = '16', fontproperties=font)
plt.xticks(size = '14', fontproperties=font)
plt.ylabel("Depth Below Soil Surface (m)", size = '16', fontproperties=font)
plt.yticks(size = '14')
plt.xlim(left=-50, right=2100)
#plt.rcParams['figure.figsize'] = [5, 6]

# To save the figure (.png):
plt.savefig('All_Sites_Combined_2022_2023_BGB_Vertical_Distribution.png', bbox_inches='tight')
# Out:
# BGB (g) Core 1 - Site A 2022    1.952
# BGB (g) Core 2 - Site A 2022    1.001
# BGB (g) Core 3 - Site A 2022    0.917
# Name: 0, dtype: float64
# The sum of the sites layer 1 is 3.87 g
# BGB (g) Core 1 - Site A 2022    1.792
# BGB (g) Core 2 - Site A 2022    1.356
# BGB (g) Core 3 - Site A 2022    0.659
# Name: 1, dtype: float64
# The sum of the sites layer 2 is 3.8070000000000004 g
# BGB (g) Core 1 - Site A 2022    1.692
# BGB (g) Core 2 - Site A 2022    0.065
# BGB (g) Core 3 - Site A 2022    1.631
# Name: 2, dtype: float64
# The sum of the sites layer 3 is 3.388 g
# BGB (g) Core 1 - Site A 2022    1.710
# BGB (g) Core 2 - Site A 2022    0.755
# BGB (g) Core 3 - Site A 2022    0.643
# Name: 3, dtype: float64
# The sum of the sites layer 4 is 3.1079999999999997 g
# BGB (g) Core 1 - Site A 2022    1.355
# BGB (g) Core 2 - Site A 2022    0.368
# BGB (g) Core 3 - Site A 2022    0.608
# Name: 4, dtype: float64
# The sum of the sites layer 5 is 2.331 g
# ...
